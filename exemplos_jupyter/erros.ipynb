# %% [markdown]
# # __Erros: Exemplos__

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from CB2325NumericaG6.erros import erro_absoluto, erro_relativo, np

# %% [markdown]
# # __Erro Absoluto:__

# %% [markdown]
# ---

# %% [markdown]
# ## Exemplos 1: Casos escalares

# %%
# Calcula o erro absoluto para cada par de valores abaixo
valores = [(10.0 , 7,0),
           (3.5 , 3.5),
           (3.5 , -3.5),
           (-4.0 , -6.0)]

for par in valores:
    v1,v2 = par[0], par[1]
    ea = erro_absoluto(v1,v2)
    print(f'Erro absoluto entre ({v1} , {v2}) = {ea}')
# Out:
# Erro absoluto entre (10.0 , 7) = 3.0
# Erro absoluto entre (3.5 , 3.5) = 0.0
# Erro absoluto entre (3.5 , -3.5) = 7.0
# Erro absoluto entre (-4.0 , -6.0) = 2.0

# %% [markdown]
# ---

# %% [markdown]
# ## Exemplos 2: Arrays NumPy

# %%
# Calcula o erro absoluto para cada par de arrays NumPy abaixo
arrays = [( np.array([100,20,5]), np.array([99,21,5]) ),
          ( np.array([10,-5.0]) , np.array([8,-4.5]) ),
          ( np.array([1.1,2.2,3.3]) , np.array([1.0,2.0,4.0]) )]

for par in arrays:
    arr1, arr2 = par[0], par[1]
    ea = erro_absoluto(arr1, arr2)
    print(f'Erro absoluto entre ({arr1} , {arr2}) = {ea}')
# Out:
# Erro absoluto entre ([100  20   5] , [99 21  5]) = [1 1 0]
# Erro absoluto entre ([10. -5.] , [ 8.  -4.5]) = [2.  0.5]
# Erro absoluto entre ([1.1 2.2 3.3] , [1. 2. 4.]) = [0.1 0.2 0.7]

# %% [markdown]
# ---

# %% [markdown]
# # __Erro relativo:__

# %% [markdown]
# ---

# %% [markdown]
# ## Exemplos 1: Casos escalares

# %%
valores = [(100.0 , 99,0),
           (50.0 , 60.0),
           (-10.0 , -11.0),
           (-4.0 , -6.0)]

for par in valores:
    v1, v2 = par[0], par[1]
    er = erro_relativo(v1, v2)
    print(f'Erro relativo entre ({v1} , {v2}) = {er}')
# Out:
# Erro relativo entre (100.0 , 99) = 0.01
# Erro relativo entre (50.0 , 60.0) = 0.2
# Erro relativo entre (-10.0 , -11.0) = 0.1
# Erro relativo entre (-4.0 , -6.0) = 0.5

# %% [markdown]
# ---

# %% [markdown]
# ## Exemplos 2: Arrays NumPy

# %%
pares = [ (np.array([100.0, 20.0, 5.0]), np.array([99.0, 21.5, 5.0])),
    (np.array([10.0, -5.0]), np.array([8.0, -4.5])),
    (np.array([1.1, 2.2, 3.3]), np.array([1.0, 2.0, 4.0])),
    (np.array([100.0, 0.0, 0.0, -10.0]), np.array([99.0, 0.0, 10.0, -11.0]))
]

for par in pares:
    arr1, arr2 = par[0],par[1]
    er = erro_relativo(arr1,arr2)
    print(f'Erro relativo entre ({arr1} , {arr2}) = {er}')
# Out:
# Erro relativo entre ([100.  20.   5.] , [99.  21.5  5. ]) = [0.01  0.075 0.   ]
# Erro relativo entre ([10. -5.] , [ 8.  -4.5]) = [0.2 0.1]
# Erro relativo entre ([1.1 2.2 3.3] , [1. 2. 4.]) = [0.09090909 0.09090909 0.21212121]
# Erro relativo entre ([100.   0.   0. -10.] , [ 99.   0.  10. -11.]) = [0.01 0.    inf 0.1 ]
